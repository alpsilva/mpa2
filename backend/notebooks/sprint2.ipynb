# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import pm4py

from datetime import datetime, timedelta

# %% [markdown]
# ## Loads

# %%
log_file_path = "./log_2_geral_datas_distribuidas.csv"

df = pd.read_csv(log_file_path, encoding = "utf-8")
df.head()
# Out:
#                      tarefa            dt_inicio  demanda_id   cliente  \
# 0           Estimar_Tamanho  2021-04-26 18:06:40         261  cliente1
# 1        Validar_Requisitos  2021-04-26 18:11:42         261  cliente1
# 2      Projetar_Arquitetura  2021-04-26 18:16:45         261  cliente1
# 3     Projetar_Modelo_Dados  2021-04-26 18:21:46         261  cliente1
# 4  Fisicalizar_Modelo_Dados  2021-04-26 18:26:47         261  cliente1
#
#   tp_demanda               dt_fim
# 0  evolutiva  2021-04-28 12:10:06
# 1  evolutiva  2021-04-28 01:56:57
# 2  evolutiva  2021-04-27 17:33:12
# 3  evolutiva  2021-04-30 13:58:17
# 4  evolutiva  2021-04-30 14:33:04

# %%
df = pm4py.format_dataframe(df, case_id='demanda_id', 
                                activity_key='tarefa', 
                                timestamp_key='dt_inicio')

log = pm4py.convert_to_event_log(df) # Transformando em log

# %%
def simplify_log(log, level, by_top=True):
    """
    Simplifies a log by taking out unpopular variantes.

    Parameters:
        log    (pm4py.objects.log) : Log
        level  (int)               : 3,5,7,9 or 12; 3 "muito baixo"; 12 "muito alto"
                                     in the case of by_top=False, percentage
        by_top (bool)              : If the filtering will be by the top apearances 
                                     instead of percentage cut
    Returns:
        filtered_log  (pm4py.objects.log) : Simplified log
    """
    # Filtering by top k apearences (default)
    if by_top:
        filtered_log = pm4py.filter_variants_top_k(log, level)
        return filtered_log
    # Filter by percentage 
    filtered_log = pm4py.filter_variants_by_coverage_percentage(log, percentage_cut)
    return filtered_log

# %%
simplify_log(log, 5)
# Out:
# []

# %% [markdown]
# # Atividades

# %% [markdown]
# Esta função engloba:
# * 3.1.1
# * 3.1.2
# * 3.1.3

# %%
from datetime import timedelta
def listar_demanda(log):
    response = []
    for trace in log:
      obj = {}
      obj ['cliente'] = trace.attributes['cliente']
      obj ['case_id'] = trace.attributes['concept:name']
      eventos = {}
      for event in trace:
        tarefa = event['tarefa']
        if(tarefa not in eventos):
          eventos[tarefa] = {
            'nome_atividade': tarefa,
            'primeira_ocorrencia': event['dt_inicio'],
            'quantidade': 0,
            'tempo': timedelta(0)
          }
        eventos[tarefa]['quantidade'] += 1
        eventos[tarefa]['tempo'] += event['dt_fim'] - event['dt_inicio']
      obj ['atividades'] = eventos
      response.append(obj)
    return response


print(len(listar_demanda(LOGS)))

# %% [markdown]
# Essa função engloba:
# - 3.3.1
# - 3.3.5
# - 3.3.6
# - 3.3.7
# - 3.3.8

# %%
def activity_info(demand : pm4py.objects.log.obj.Event, order : bool = False):
    """
    Returns each unique activity in a demand and its # of ocurrences.

    Parameters:
        demand (pm4py.objects.log.obj.Event) : demand to be analysed
        order (bool) : if activities are ordered by # of ocurrences decreasing
    Returns:
        activities (dict) : dict with activities as key and its information as values
            inside of this dict we have:
            key: activity
            value:
                dict (activity)
                    keys :
                        - freq
                        - name
                        - first_occurrence 
                        - total_duration
                        - occurrences (list of dicts)
                            dict
                                - executor
                                - start
                                - finish
                                - duration
    """
    activities = {} # Dict onde as chaves sao nomes unicos de atividades de uma dada demanda
    for activity in demand:
        name = activity['tarefa'] # Tarefa diz o nome da atividade (basicamente o id)

        # Try except para checar se a tarefa já foi acrescentada como chave do dicionario
        try:
            # Somando a quantidade de ocorrencias e alterando a primeira ocorrencia registrada se for o caso
            activities[name]['freq'] += 1
            if activity['dt_inicio'] < activities[name]['first_occurrence']:
                activities[name]['first_occurrence'] = activity['dt_inicio']
        except:
            # Inicializando atividade, que tambem é um dict de informações
            activities[name] = {}
            activities[name]['freq'] = 1
            activities[name]['name'] = name
            activities[name]['first_occurrence'] = activity['dt_inicio']
            activities[name]['total_duration'] = timedelta(days=0)
            activities[name]['occurrences'] = []
        
        # Aqui temos o dicionario associado a cada ocorrencia
        ocur_info = {}
        ocur_info['executor'] = activity['cliente']                        # Quem fez
        ocur_info['start'] = activity['dt_inicio']                         # Inicio
        ocur_info['finish'] = activity['dt_fim']                           # Fim
        ocur_info['duration'] = activity['dt_fim'] - activity['dt_inicio'] # Duração
        # Ocurrences é um array de dicionários com as informações das ocorrências da atividade
        activities[name]['occurrences'].append(ocur_info)

        activities[name]['total_duration'] = activities[name]['total_duration'] + ocur_info['duration']
    
    if order:
        activities = {k : v for k, v in sorted(activities.items(), key=lambda item: item[1]['freq'], reverse=True)}

    return activities

# %%
a = activity_info(log[0], order=True)

# %%
a
# Out:
# {'Analise_Risco_Produto': {'freq': 42,
#   'name': 'Analise_Risco_Produto',
#   'first_occurrence': Timestamp('2021-05-31 19:41:45+0000', tz='UTC'),
#   'total_duration': Timedelta('84 days 01:17:46'),
#   'occurrences': [{'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 19:41:45+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 14:57:12+0000', tz='UTC'),
#     'duration': Timedelta('1 days 19:15:27')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 20:07:09+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 10:01:56+0000', tz='UTC'),
#     'duration': Timedelta('1 days 13:54:47')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 20:12:12+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 19:21:53+0000', tz='UTC'),
#     'duration': Timedelta('3 days 23:09:41')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 20:32:24+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 09:03:34+0000', tz='UTC'),
#     'duration': Timedelta('3 days 12:31:10')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 20:47:31+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-05 02:50:06+0000', tz='UTC'),
#     'duration': Timedelta('4 days 06:02:35')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 21:22:49+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 16:19:42+0000', tz='UTC'),
#     'duration': Timedelta('2 days 18:56:53')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 21:33:01+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 11:32:04+0000', tz='UTC'),
#     'duration': Timedelta('3 days 13:59:03')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 21:48:05+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 22:51:43+0000', tz='UTC'),
#     'duration': Timedelta('2 days 01:03:38')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 21:58:10+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 13:18:20+0000', tz='UTC'),
#     'duration': Timedelta('1 days 15:20:10')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 22:08:14+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 11:59:20+0000', tz='UTC'),
#     'duration': Timedelta('2 days 13:51:06')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 22:18:19+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 19:58:22+0000', tz='UTC'),
#     'duration': Timedelta('2 days 21:40:03')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 22:28:27+0000', tz='UTC'),
#     'finish': Timestamp('2021-06
0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 17:26:29+0000', tz='UTC'),
#     'duration': Timedelta('2 days 07:39:12')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 10:07:34+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 02:53:29+0000', tz='UTC'),
#     'duration': Timedelta('0 days 16:45:55')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 10:12:43+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 07:42:04+0000', tz='UTC'),
#     'duration': Timedelta('0 days 21:29:21')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 10:38:15+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-05 15:03:36+0000', tz='UTC'),
#     'duration': Timedelta('4 days 04:25:21')}]},
#  'Corrigir_Erros': {'freq': 20,
#   'name': 'Corrigir_Erros',
#   'first_occurrence': Timestamp('2021-05-31 19:36:44+0000', tz='UTC'),
#   'total_duration': Timedelta('47 days 19:03:04'),
#   'occurrences': [{'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 19:36:44+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 19:28:36+0000', tz='UTC'),
#     'duration': Timedelta('1 days 23:51:52')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 20:37:28+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 18:35:12+0000', tz='UTC'),
#     'duration': Timedelta('3 days 21:57:44')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 21:12:46+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 03:12:32+0000', tz='UTC'),
#     'duration': Timedelta('2 days 05:59:46')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 22:03:13+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 02:30:02+0000', tz='UTC'),
#     'duration': Timedelta('3 days 04:26:49')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 22:38:32+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 20:52:40+0000', tz='UTC'),
#     'duration': Timedelta('2 days 22:14:08')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 23:13:49+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 00:56:08+0000', tz='UTC'),
#     'duration': Timedelta('1 days 01:42:19')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 00:19:42+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 23:20:05+0000', tz='UTC'),
#     'duration': Timedelta('1 days 23:00:23')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 01:05:20+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 04:02:38+0000', tz='UTC'),
#     'duration': Timedelta('3 days 02:57:18')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 02:46:38+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 19:08:54+0000', tz='UTC'),
#     'duration': Timedelta('2 days 16:22:16')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 03:37:29+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 05:04:29+0000', tz='UTC'),
#     'duration': Timedelta('1 days 01:27:00')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 04:18:05+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 12:53:03+0000', tz='UTC'),
#     'duration': Timedelta('1 days 08:34:58')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 05:24:01+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 03:28:54+0000', tz='UTC'),
#     'duration': Timedelta('1 days 22:04:53')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 06:04:25+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 07:05:27+0000', tz='UTC'),
#     'duration': Timedelta('2 days 01:01:02')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 06:29:40+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 02:57:34+0000', tz='UTC'),
#     'duration': Timedelta('2 days 20:27:54')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 06:44:56+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-01 23:43:13+0000', tz='UTC'),
#     'duration': Timedelta('0 days 16:58:17')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 07:15:19+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 23:16:37+0000', tz='UTC'),
#     'duration': Timedelta('3 days 16:01:18')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 08:11:02+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 09:55:39+0000', tz='UTC'),
#     'duration': Timedelta('3 days 01:44:37')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 08:41:21+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 12:47:13+0000', tz='UTC'),
#     'duration': Timedelta('2 days 04:05:52')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 09:01:34+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 17:27:48+0000', tz='UTC'),
#     'duration': Timedelta('2 days 08:26:14')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 10:02:31+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 21:40:55+0000', tz='UTC'),
#     'duration': Timedelta('3 days 11:38:24')}]},
#  'Testar': {'freq': 20,
#   'name': 'Testar',
#   'first_occurrence': Timestamp('2021-05-31 21:02:44+0000', tz='UTC'),
#   'total_duration': Timedelta('39 days 21:47:25'),
#   'occurrences': [{'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 21:02:44+0000', tz='UTC'),
#     'finish': Timestamp('2021-06
0000', tz='UTC'),
#     'finish': Timestamp('2021-06-01 16:25:19+0000', tz='UTC'),
#     'duration': Timedelta('0 days 10:25:57')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 06:39:48+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 21:49:07+0000', tz='UTC'),
#     'duration': Timedelta('1 days 15:09:19')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 08:26:08+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 02:20:50+0000', tz='UTC'),
#     'duration': Timedelta('0 days 17:54:42')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 09:26:57+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-05 07:01:59+0000', tz='UTC'),
#     'duration': Timedelta('3 days 21:35:02')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 10:23:03+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 17:37:18+0000', tz='UTC'),
#     'duration': Timedelta('2 days 07:14:15')}]},
#  'Projetar_Modelo_Dados': {'freq': 17,
#   'name': 'Projetar_Modelo_Dados',
#   'first_occurrence': Timestamp('2021-05-31 19:46:48+0000', tz='UTC'),
#   'total_duration': Timedelta('43 days 13:21:44'),
#   'occurrences': [{'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 19:46:48+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-01 10:55:34+0000', tz='UTC'),
#     'duration': Timedelta('0 days 15:08:46')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 20:17:16+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 22:21:33+0000', tz='UTC'),
#     'duration': Timedelta('3 days 02:04:17')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 20:52:40+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 15:27:23+0000', tz='UTC'),
#     'duration': Timedelta('1 days 18:34:43')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 21:53:07+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-05 00:43:09+0000', tz='UTC'),
#     'duration': Timedelta('4 days 02:50:02')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 22:43:35+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 00:36:06+0000', tz='UTC'),
#     'duration': Timedelta('3 days 01:52:31')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 23:34:09+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 03:29:02+0000', tz='UTC'),
#     'duration': Timedelta('2 days 03:54:53')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 23:54:23+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 22:42:38+0000', tz='UTC'),
#     'duration': Timedelta('3 days 22:48:15')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 00:04:38+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 08:06:33+0000', tz='UTC'),
#     'duration': Timedelta('2 days 08:01:55')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 01:55:58+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 10:43:23+0000', tz='UTC'),
#     'duration': Timedelta('1 days 08:47:25')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 03:17:09+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 06:00:45+0000', tz='UTC'),
#     'duration': Timedelta('1 days 02:43:36')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 03:42:34+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-05 06:25:04+0000', tz='UTC'),
#     'duration': Timedelta('4 days 02:42:30')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 04:28:11+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 18:17:38+0000', tz='UTC'),
#     'duration': Timedelta('1 days 13:49:27')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 05:13:56+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 12:25:20+0000', tz='UTC'),
#     'duration': Timedelta('1 days 07:11:24')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 07:05:13+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-05 07:41:52+0000', tz='UTC'),
#     'duration': Timedelta('4 days 00:36:39')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 07:20:22+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 21:22:01+0000', tz='UTC'),
#     'duration': Timedelta('1 days 14:01:39')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 08:56:33+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 19:10:45+0000', tz='UTC'),
#     'duration': Timedelta('3 days 10:14:12')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 09:57:29+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-05 07:56:59+0000', tz='UTC'),
#     'duration': Timedelta('3 days 21:59:30')}]},
#  'Projetar_Arquitetura': {'freq': 14,
#   'name': 'Projetar_Arquitetura',
#   'first_occurrence': Timestamp('2021-05-31 19:56:56+0000', tz='UTC'),
#   'total_duration': Timedelta('35 days 13:55:11'),
#   'occurrences': [{'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 19:56:56+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 04:26:14+0000', tz='UTC'),
#     'duration': Timedelta('3 days 08:29:18')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 20:22:18+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-05 01:20:14+0000', tz='UTC'),
#     'duration': Timedelta('4 days 04:57:56')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 22:48:36+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 03:22:26+0000', tz='UTC'),
#     'duration': Timedelta('1 days 04:33:50')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 23:23:57+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 06:43:22+0000', tz='UTC'),
#     'duration': Timedelta('3 days 07:19:25')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 00:09:39+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 21:34:18+0000', tz='UTC'),
#     'duration': Timedelta('2 days 21:24:39')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 03:47:38+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-05 04:43:42+0000', tz='UTC'),
#     'duration': Timedelta('4 days 00:56:04')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 04:33:15+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 17:34:19+0000', tz='UTC'),
#     'duration': Timedelta('3 days 13:01:04')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 05:08:54+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 16:29:21+0000', tz='UTC'),
#     'duration': Timedelta('1 days 11:20:27')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 06:09:28+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 09:35:01+0000', tz='UTC'),
#     'duration': Timedelta('2 days 03:25:33')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 07:25:23+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-01 20:01:19+0000', tz='UTC'),
#     'duration': Timedelta('0 days 12:35:56')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 07:45:41+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 08:27:25+0000', tz='UTC'),
#     'duration': Timedelta('2 days 00:41:44')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 08:16:04+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-05 02:44:39+0000', tz='UTC'),
#     'duration': Timedelta('3 days 18:28:35')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 09:06:37+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-03 08:35:52+0000', tz='UTC'),
#     'duration': Timedelta('1 days 23:29:15')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 09:32:03+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-02 12:43:28+0000', tz='UTC'),
#     'duration': Timedelta('1 days 03:11:25')}]},
#  'Reuniao_tecnica': {'freq': 2,
#   'name': 'Reuniao_tecnica',
#   'first_occurrence': Timestamp('2021-06-01 10:43:20+0000', tz='UTC'),
#   'total_duration': Timedelta('5 days 18:28:13'),
#   'occurrences': [{'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 10:43:20+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 12:08:49+0000', tz='UTC'),
#     'duration': Timedelta('3 days 01:25:29')},
#    {'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 10:48:22+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 03:51:06+0000', tz='UTC'),
#     'duration': Timedelta('2 days 17:02:44')}]},
#  'Estimar_Tamanho': {'freq': 1,
#   'name': 'Estimar_Tamanho',
#   'first_occurrence': Timestamp('2021-05-31 19:31:41+0000', tz='UTC'),
#   'total_duration': Timedelta('3 days 09:37:16'),
#   'occurrences': [{'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 19:31:41+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 05:08:57+0000', tz='UTC'),
#     'duration': Timedelta('3 days 09:37:16')}]},
#  'Documentar_Req_Funcionais': {'freq': 1,
#   'name': 'Documentar_Req_Funcionais',
#   'first_occurrence': Timestamp('2021-05-31 20:02:00+0000', tz='UTC'),
#   'total_duration': Timedelta('4 days 02:36:28'),
#   'occurrences': [{'executor': 'cliente1',
#     'start': Timestamp('2021-05-31 20:02:00+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 22:38:28+0000', tz='UTC'),
#     'duration': Timedelta('4 days 02:36:28')}]},
#  'Homologar': {'freq': 1,
#   'name': 'Homologar',
#   'first_occurrence': Timestamp('2021-06-01 10:53:24+0000', tz='UTC'),
#   'total_duration': Timedelta('2 days 23:51:05'),
#   'occurrences': [{'executor': 'cliente1',
#     'start': Timestamp('2021-06-01 10:53:24+0000', tz='UTC'),
#     'finish': Timestamp('2021-06-04 10:44:29+0000', tz='UTC'),
#     'duration': Timedelta('2 days 23:51:05')}]}}
